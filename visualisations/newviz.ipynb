# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'online', 'pretrained', 'retrained', 'single')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'continual2')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continualrandom', 'retrained')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continualrandom', 'continualfullrandom')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continualrandom', 'continualrandomfewermp')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('retrained', 'retrainedreuseweights')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'oldcontinual')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'online', 'pretrained', 'retrained', 'single', 'continualrand')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}futureskipped.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('retrained', 'pretrained', 'single', 'online', 'continualrandom')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,2]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')
plt.xlabel('Timeframe')
plt.ylabel('NDCG@10')
plt.ylim([0, .5])
# NDCG
# Out:
# (0, 0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continualrandom', 'continual')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    print(data.mean())
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')
plt.xlabel('Timeframe')
plt.ylabel('HR@10')
# Out:
# 0.4796462665674685
# 0.46916270287316153
# Text(0, 0.5, 'HR@10')

# %%
import matplotlib.pyplot as plt

d = {
    .25: 0.18421052631578946,
    .5:  0.23519736842105263,
    1:   0.26151315789473684,
    1.5: 0.34868421052631576,
    2:   0.37993421052631576,
    3:   0.4309210526315789,
    4:   0.48848684210526316,
    5:   0.524671052631579,
    6:   0.537828947368421,
    7:   0.5460526315789473,
    8:   0.5361842105263158,
    9:   0.5625,
    10:  0.5904605263157895,
    11:  0.6134868421052632,
    12:  0.5970394736842105,
    13:  0.5805921052631579,
    14:  0.6019736842105263,
    15:  0.625,
    16:  0.6381578947368421,
    17:  0.618421052631579,
    18:  0.6036184210526315,
    19:  0.6266447368421053,
    20:  0.6118421052631579,
    21:  0.6535433070866141,
    22:  0.631578947368421,
    23:  0.631578947368421,
    24:  0.6134868421052632,
    25:  0.694078947368421,
}

x = list(d.keys())
y = list(d.values())
# x = [speedup(theta) for theta in x]

plt.plot(x, y)
# plt.xscale('log')
plt.plot(x, [0.5526315789473685] * len(x))

print(sum(d.values())/len(d.values()))
# Out:
# 0.5345602872831686

# %%
import matplotlib.pyplot as plt

# data = [0.84507, 0.852308, 0.802168, 0.810881, 0.804444, 0.80744, 0.80791,
#         0.801418, 0.7968, 0.801562, 0.819783, 0.814266, 0.821159, 0.81875]
# plt.plot(data, label='ewc')

data = [0.84507, 0.855385, 0.658537, 0.665803, 0.66, 0.66302, 0.691149,
        0.689716, 0.7456, 0.767187, 0.738482, 0.736205, 0.774559, 0.7725]
plt.plot(data, label='ewc')

# data = [0.84507, 0.849231, 0.802168, 0.805699, 0.802222, 0.80744, 0.80791,
#         0.801418, 0.7952, 0.798438, 0.819783, 0.812921, 0.821159, 0.82375]
# plt.plot(data, label='no ewc')

data = [0.84507, 0.855385, 0.647696, 0.658031, 0.633333, 0.636761, 0.683616,
        0.696809, 0.7424, 0.767187, 0.726287, 0.722746, 0.779597, 0.7775]
plt.plot(data, label='no ewc')

plt.legend(loc='upper right')

# %%
def speedup(theta):
    ret = sum(range(1, 24))
    cont = 0
    for i in range(1, 24):
        cont += i if i < theta else theta
    return ret/cont

x = range(1, 24)
y = [speedup(theta) for theta in x]

plt.plot(x, y)

# %%
(2 * 60 + 11)/(60 + 35)
# Out:
# 1.3789473684210527

# %%
speedup(1.5)
# Out:
# 8.117647058823529

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'online', 'pretrained', 'retrained', 'single')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'online', 'pretrained', 'retrained', 'single')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}shuffuture.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = ('continual', 'online', 'pretrained', 'retrained', 'single')

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}{aspect}tsfuture.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')

# %%
import matplotlib.pyplot as plt

d = {
    .25: 0.28618421052631576,
    .5:  0.3223684210526316,
    1:   0.34539473684210525,
    1.5: 0.3684210526315789,
    2:   0.4194078947368421,
    3:   0.4654605263157895,
    4:   0.4917763157894737,
    5:   0.53125,
    6:   0.5427631578947368,
    7:   0.5493421052631579,
    8:   0.5641447368421053,
    9:   0.5526315789473685,
    10:  0.5740131578947368,
    11:  0.59375,
    12:  0.6217105263157895,
    13:  0.6134868421052632,
    14:  0.625,
    15:  0.6167763157894737,
    16:  0.6167763157894737,
    17:  0.6151315789473685,
    18:  0.625,
    19:  0.631578947368421,
    20:  0.6644736842105263,
    21:  0.6398026315789473,
    22:  0.6546052631578947,
    23:  0.6578947368421053,
    24:  0.618421052631579,
    25:  0.65625,
}

x = list(d.keys())
y = list(d.values())
# x = [speedup(theta) for theta in x]
plt.plot(x, y)

d = {
    .25: 0.18421052631578946,
    .5:  0.23519736842105263,
    1:   0.26151315789473684,
    1.5: 0.34868421052631576,
    2:   0.37993421052631576,
    3:   0.4309210526315789,
    4:   0.48848684210526316,
    5:   0.524671052631579,
    6:   0.537828947368421,
    7:   0.5460526315789473,
    8:   0.5361842105263158,
    9:   0.5625,
    10:  0.5904605263157895,
    11:  0.6134868421052632,
    12:  0.5970394736842105,
    13:  0.5805921052631579,
    14:  0.6019736842105263,
    15:  0.625,
    16:  0.6381578947368421,
    17:  0.618421052631579,
    18:  0.6036184210526315,
    19:  0.6266447368421053,
    20:  0.6118421052631579,
    21:  0.6535433070866141,
    22:  0.631578947368421,
    23:  0.631578947368421,
    24:  0.6134868421052632,
    25:  0.694078947368421,
}

x = list(d.keys())
y = list(d.values())
# x = [speedup(theta) for theta in x]


plt.plot(x, y)
# plt.xscale('log')
plt.plot(x, [0.5526315789473685] * len(x))

print(sum(d.values())/len(d.values()))
# Out:
# 0.5345602872831686

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('00', 'no ewc'),
    ('01', 'ewc'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('00', 'no ewc'),
    ('10', 'ewc'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'no ewc'),
    ('11', 'ewc'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'continual'),
    ('age', 'age'),
    # ('bn', 'bn'),
    # ('imp', 'imp'),
    # ('impnonrand', 'impnonrand'),
    # ('neveragian', 'neveragain'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'continual'),
    # ('age', 'age'),
    ('bn', 'bn'),
    # ('imp', 'imp'),
    # ('impnonrand', 'impnonrand'),
    # ('neveragian', 'neveragain'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'random'),
    # ('age', 'age'),
    # ('bn', 'bn'),
    ('imp', 'importance'),
    # ('impnonrand', 'impnonrand'),
    # ('neveragian', 'neveragain'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'random'),
    # ('age', 'age'),
    # ('bn', 'bn'),
    # ('imp', 'imp'),
    ('impnonrand', 'importance random'),
    # ('neveragian', 'neveragain'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'random'),
    # ('age', 'age'),
    # ('bn', 'bn'),
    # ('imp', 'imp'),
    # ('impnonrand', 'impnonrand'),
    ('neveragian', 'neveragain'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    ('10', 'random'),
    # ('age', 'age'),
    # ('bn', 'bn'),
    # ('imp', 'imp'),
    # ('impnonrand', 'impnonrand'),
    ('embdiv', 'embdiv'),
)

for aspect in aspects:
    data = np.genfromtxt(f'{timeframes}continual{aspect[0]}future.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect[1])

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

timeframes = 25
aspects = (
    'ce', 'mse', 'bpr'
)

for aspect in aspects:
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    plt.ylim(0, 1)


    plt.plot(data, label=aspect)

plt.ylim(0.2, 0.8)

plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt

aspects = (
    'base', 'base_rehersal_0.5', 'base_rehersal_0.75'
)
names = (
    'base (0%)', 'rehersal (50%)', 'rehersal (75%)'
)

for name, aspect in zip(names, aspects):
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    # index from 1
    plt.plot(np.arange(1, len(data)+1), data, label=name)
    
plt.ylim(0.5, 0.8)
plt.legend(loc='upper right')
plt.xlabel('Timestep')
plt.ylabel('Accuracy')
# plt.title('Rehersal impact on accuracy on users from all timesteps')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

aspects = (
    'latest', 'latest_rehersal_0.5', 'latest_rehersal_0.75'
)

names = (
    'base (0%)', 'rehersal (50%)', 'rehersal (75%)'
)

fig, ax = plt.subplots()

for name, aspect in zip(names, aspects):
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    # rolling average
    data = [np.mean(data[:i]) for i in range(1, len(data)+1)]
    ax.plot(np.arange(1, len(data)+1), data, label=name)

plt.ylim(0.5, 0.8)
plt.legend(loc='upper right')
plt.xlabel('Timestep')
plt.ylabel('Accuracy')
# plt.title('Rehersal impact on accuracy on users from all timesteps')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
import numpy as np
import matplotlib.pyplot as plt

aspects = (
    'base', '2c', '4c', 'base_rehersal_0.5', '2c_rehersal', '4c_rehersal'
)
names = (
    'base (c)', 'base (2c)', 'base (4c)', 'rehersal (c)', 'rehersal (2c)', 'rehersal (4c)'
)

for name, aspect in zip(names, aspects):
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    # index from 1
    plt.plot(np.arange(1, len(data)+1), data, label=name)
    
plt.ylim(0.5, 0.8)
plt.legend(loc='upper right')
plt.xlabel('Timestep')
plt.ylabel('Accuracy')
# plt.title('Rehersal impact on accuracy on users from all timesteps')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
import numpy as np
import matplotlib.pyplot as plt

aspects = (
    '4c', '4c_rehersal'
)

for aspect in aspects:
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')
plt.xlabel('Timestamp')
plt.ylabel('Accuracy')
plt.title('Increased computational budget (4x)')
# Out:
# Text(0.5, 1.0, 'Increased computational budget (4x)')

# %%
import numpy as np
import matplotlib.pyplot as plt

aspects = (
    'base_rehersal_0.5', '2c_rehersal', '4c_rehersal'
)

for aspect in aspects:
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')
plt.xlabel('Timestamp')
plt.ylabel('Accuracy')
plt.title('Impact of the size of computational budget when using rehearsal')
# Out:
# Text(0.5, 1.0, 'Impact of the size of computational budget when using rehearsal')

# %%
import numpy as np
import matplotlib.pyplot as plt

aspects = (
    '2t', '2t_rehersal'
)

for aspect in aspects:
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')
plt.xlabel('Timestamp')
plt.ylabel('Accuracy')
plt.title('Increased no of tasks (2x)')
# Out:
# Text(0.5, 1.0, 'Increased no of tasks (2x)')

# %%
import numpy as np
import matplotlib.pyplot as plt

aspects = (
    '4t', '4t_rehersal'
)

for aspect in aspects:
    data = np.genfromtxt(f'{aspect}.csv', delimiter=',')
    data = data[:,1]
    plt.plot(data, label=aspect)

plt.legend(loc='upper right')
plt.xlabel('Timestamp')
plt.ylabel('Accuracy')
plt.title('Increased no of tasks (4x)')
# Out:
# Text(0.5, 1.0, 'Increased no of tasks (4x)')

# %%
pwd
# Out:
# '/homes/55/ion/ContinualMetapathGNN/visualisations'
